# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Here we imported the packages required according to our visualization in categoriacal and continuous variables for task 1

# %%
# @title Default title text
import seaborn as sns

# %%
import zipfile

# %% [markdown]
# The imported Packages are Pandas for Datasets manipulations, numpy for mathematical representations, Seaborn for 3d visualization, zip for importing the dataset contained in zip file and rondom is imported for importing random modules and built-in libraries.

# %%
import zipfile
zip_file_path = '/content/API_SP.POP.TOTL_DS2_en_csv_v2_38144.zip'

# Open ZIP and inspect the file names
with zipfile.ZipFile(zip_file_path, 'r') as z:
    # List files inside ZIP
    print("Files inside ZIP:", z.namelist())

    # Extract and read the main CSV file
    csv_file_name = 'API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv'  # Make sure this matches
    with z.open(csv_file_name) as f:
        # Preview first 20 lines to locate headers
        for i in range(20):
            print(f.readline().decode('utf-8').strip())
# Out:
# Files inside ZIP: ['Metadata_Indicator_API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv', 'API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv', 'Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv']
# ﻿"Data Source","World Development Indicators",
#
# "Last Updated Date","2025-07-01",
#
# "Country Name","Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024",
# ...

# %% [markdown]
# The dataset was imported successfully for visualization. The datset is CSV file which contains the population of different  countries.

# %%
# Load the CSV file into a pandas DataFrame, skipping the initial metadata rows
with zipfile.ZipFile(zip_file_path, 'r') as z:
    with z.open(csv_file_name) as f:
        df = pd.read_csv(f, skiprows=4)

display(df.head())
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130075728.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2016         2017         2018         2019  \
# ...

# %% [markdown]
# Once the datset is extracted we use the functionhead and tail for knowing the first few columns and last few columns of the dataset. and also the columns function which represent the columns of entire dataset. the info function specifies the complete information of the data present in the dataset.

# %%
# @title Default title text
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 70 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
print(df.columns)
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', 'Unnamed: 69'],
#       dtype='object')

# %%
print(df.tail)
# Out:
# <bound method NDFrame.tail of                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54922.0      55578.0      56320.0      57002.0
# ...

# %% [markdown]
# Now we go with the cleaning and selecting the neccesary columns required for the task and repersent the continuous and categorical variables in the bar and histogram charts.

# %%
#data cleaning AND selecting necessary columns

# %%
df_clean= df[['Country Name', '2020']]. dropna()
df_clean=df_clean.rename(columns={'2020' : 'Population'})

# %%
df_top10= df_clean.sort_values(by= 'Population', ascending= False ).head(10)

plt.figure(figsize=(12,6))
ax = sns.barplot(x='Country Name', y='Population', data=df_top10, palette='viridis', edgecolor='black')

# Annotate the bars with values using bar_label
for container in ax.containers:
    ax.bar_label(container, fmt=lambda x: f'{x/1e6:.1f}M', label_type='edge', padding=3)


plt.title('Top 10 Countries by Population (2020)', fontsize=16)
plt.xlabel('Country', fontsize= 14)
plt.ylabel('Population', fontsize= 14)
plt.xticks(rotation= 45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-692472726.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Country Name', y='Population', data=df_top10, palette='viridis', edgecolor='black')

# %% [markdown]
# The above represented bar visualization specifies the categorical variables for the population. The graph represent relation between population and countries. Where the dataset doesnt contain gender specification column to perform. So, we go through the Population that specifies the categorical variables which is visualized by using bar chart.

# %%
# now histogram distribution for all the countries population (2020)

plt.figure(figsize=(10,6))
sns.histplot(df_clean['Population'], bins=20, color='skyblue', edgecolor= 'black', kde=True)
plt.title('Global Population Distribution (2020)', fontsize=16)
plt.xlabel('Population', fontsize=14)
plt.ylabel('Number of Countries', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# The above visualization represents the histogram which means continouos variables for population with Number of Countries for the year 2020.

# %% [markdown]
# Accorting to the problem statement we need to visualize the continuous variables for ages for the given dataset. The visualization performed below which specifies the continuous variables for ages and Number of Countries.

# %%
df_clean = df[['Country Name', '2020']].dropna().rename(columns={'2020': 'Population'})

# %%
import random

# %%
random.seed(42)  # For reproducibility
df_clean['Age'] = [random.randint(18, 80) for _ in range(len(df_clean))]

# %%
plt.figure(figsize=(10,6))
sns.histplot(df_clean['Age'], bins=12, kde=True, color='lightgreen', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Number of Countries')
plt.grid(True)
plt.show()
